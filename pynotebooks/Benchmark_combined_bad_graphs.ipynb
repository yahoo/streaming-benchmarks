# %% [markdown]
# # Flink Spark Storm Beam Benchmarks
# Initial Statistics
# ------
#
# This test was performed with the AdvertisingTopology reading from 5 kafka instances.
# The kafka instances were collectively fed json-serialized events at various throughputs:
#
#  - 50000/s
#  - 60000/s
#  - 70000/s
#  - 90000/s
#  - 110000/s
#  - 120000/s
#  - 130000/s
#  - 135000/s
#  - 150000/s
#  - 170000/s
#
# ### Graphs
# Counts were calculated by the topology in 10-second windows, and updated counts were written to the redis database once per second.
#
# Because we send updates to redis once per second, we expect most of the end-to-end latency measurments between kafka and redis to be less than 1000ms.
#
# #### Histogram
# The first graph is a normalized histogram of the amount of time in ms it took for a window to get its final update after the window officially ended. That is, once events stop being emitted for a window, this is how long it took for the final counts to be written. As expected, because of the 1s publishing period, the graph has a sharp dropoff at 1000ms - except for the 150000/s throughput in cyan. This is where the topology began to get behind on processing stuff from kafka, and indicates the upper bound of throughput that this topology will handle.
#
# #### Percentiles
# The rest of the graphs compare the percentiles of end-to-end latency (end-to-end being kafka producer to redis database) They don't measure on the granularity of tuples, but instead measure how long it takes for a window to converge on its final value after the window has ended. In other words, they measure the length of time between the final tuple for a given window being produced, and that tuple's data being written into redis.
#
# The first pair is end-to-end after the window close, and the second pair is end-to-end after the expected 1000ms latency.
#
# #### Setup
# - 1 Worker Node - 72 cores 384G (Parallelism 72)
# - 5 Kafka Server Instances
# - 10 Kafka Producer Instances
# - 3 Zookeeper quorum
# - 1 Redis Server Instance
#
# #### Hardware Configuration
# - Summary:	Lenovo HR630X, 2 x Xeon Gold 6240 2.60GHz, 376GB / 384GB 2933MT/s DDR4
# - System:		Lenovo HR630X, C-xz/384/0
# - Processors:	2 x Xeon Gold 6240 2.60GHz (HT enabled, 36 cores, 72 threads)
# - Memory:		376GB / 384GB 2933MT/s DDR4 == 12 x 32GB, 12 x empty
# - Disk:		sda (ahci2): 1.0TB (6%) == 1 x 1TB 7.2K SATA 600MB/s ST1000NM0065-1VT10C
# - Disk-Control:	ahci0: Intel C620 Series Chipset Family SSATA Controller [AHCI mode]
# - Disk-Control:	ahci1: Intel C620 Series Chipset Family SATA Controller [AHCI mode]
# - Network:	3b:00.0 (mlx5_core0): Mellanox MT27710 Family [ConnectX-4 Lx]
# - OS:		RHEL Server 7.6, Linux 3.10.0-957.21.3.el7.YAHOO.20190617.34.x86_64 x86_64, 64-bit
# - BIOS:		LENOVO HR6N0609 06/13/2019, rev 6.9

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def get_filtered_updated(filename, window_size_ms):
    update_times = np.loadtxt(filename, dtype=int)
    filtered_times = [x - window_size_ms for x in update_times if x >= window_size_ms]
    return filtered_times

# %%
def get_avg_latency(filename, window_size_ms):
    update_times = np.loadtxt(filename, dtype=int)
    filtered_times = [x - window_size_ms for x in update_times if x >= window_size_ms]
    return np.average(filtered_times)

# %% [markdown]
# # Average End to End Latency for Storm, Flink, Spark Streaming with checkpointing and acking enabled

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

storm_files = [
         ("../runs/results_chkpt/STORM/50000/updated.txt"),
         ("../runs/results_chkpt/STORM/70000/updated.txt"),
         ("../runs/results_chkpt/STORM/90000/updated.txt"),
         ("../runs/results_chkpt/STORM/110000/updated.txt"),
         ("../runs/results_chkpt/STORM/130000/updated.txt"),
         ("../runs/results_chkpt/STORM/135000/updated.txt"),
         ("../runs/results_chkpt/STORM/150000/updated.txt"),
         ("../runs/results_chkpt/STORM/170000/updated.txt")
        ]

flink_files = [
         ("../runs/results_chkpt/FLINK/50000/updated.txt"),
         ("../runs/results_chkpt/FLINK/70000/updated.txt"),
         ("../runs/results_chkpt/FLINK/90000/updated.txt"),
         ("../runs/results_chkpt/FLINK/110000/updated.txt"),
         ("../runs/results_chkpt/FLINK/130000/updated.txt"),
         ("../runs/results_chkpt/FLINK/135000/updated.txt"),
         ("../runs/results_chkpt/FLINK/150000/updated.txt"),
         ("../runs/results_chkpt/FLINK/170000/updated.txt")
        ]

flink_files_reuse = [
         ("../runs/results_flink_reuse/FLINK/50000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/70000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/90000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/110000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/130000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/130000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/150000/updated.txt"),
         ("../runs/results_flink_reuse/FLINK/170000/updated.txt")
        ]

spark_ss_files = [
         ("../runs/results/SS_SPARK/50000/updated.txt"),
         ("../runs/results/SS_SPARK/70000/updated.txt"),
         ("../runs/results/SS_SPARK/90000/updated.txt"),
         ("../runs/results/SS_SPARK/110000/updated.txt"),
         ("../runs/results/SS_SPARK/130000/updated.txt"),
         ("../runs/results/SS_SPARK/135000/updated.txt"),
         ("../runs/results/SS_SPARK/150000/updated.txt"),
         ("../runs/results/SS_SPARK/170000/updated.txt")
        ]

avg_latency_storm = [get_avg_latency(filename, window_size_ms) for filename in storm_files]
avg_latency_flink = [get_avg_latency(filename, window_size_ms) for filename in flink_files]
avg_latency_flink_reuse = [get_avg_latency(filename, window_size_ms) for filename in flink_files_reuse]
avg_latency_spark_ss = [get_avg_latency(filename, window_size_ms) for filename in spark_ss_files]

#legend=['Storm','Flink', 'Spark SS', 'FLINK OBJ REUSE']
legend=['Storm','Flink', 'Spark SS', 'Flink Object Reuse']


labels = ['50000', '70000', '90000', '110000', '130000', '135000', '150000', '170000']
f = plt.figure(num=None, figsize=(15, 10))
plt.xticks(range(len(avg_latency_storm)), labels)

plt.bar(np.arange(len(avg_latency_storm)), avg_latency_storm, width =0.2) 
plt.bar(np.arange(len(avg_latency_flink)) + 0.2, avg_latency_flink, width =0.2)
plt.bar(np.arange(len(avg_latency_spark_ss)) + 0.4, avg_latency_spark_ss, width =0.2) 
plt.bar(np.arange(len(avg_latency_flink_reuse)) + 0.6, avg_latency_flink_reuse, width =0.2)

plt.xlabel('Load generated in events/sec')
plt.ylabel('Avg latency for last update time (in ms after window ended)')
plt.title('Last Window Update Times (Estimated end-to-end avg latency) - Storm, Flink, Spark SS (Acking/Checkpointing Enabled)')
plt.legend(legend, loc=2)
plt.show()
#f.savefig("Storm_220_hist.pdf", bbox_inches='tight')

# %% [markdown]
# # Storm Benchmarks - 2.2.0

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/STORM/50000/updated.txt", "green", "50000"),
         ("../runs/results/STORM/70000/updated.txt", "red", "70000"),
         ("../runs/results/STORM/90000/updated.txt", "blue", "90000"),
         ("../runs/results/STORM/110000/updated.txt", "yellow", "110000"),
         ("../runs/results/STORM/130000/updated.txt", "purple", "130000"),
         ("../runs/results/STORM/135000/updated.txt", "purple", "135000"),
         ("../runs/results/STORM/150000/updated.txt", "orange", "150000"),
         ("../runs/results/STORM/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Storm_220_hist.pdf", bbox_inches='tight')

# %% [markdown]
# ## Percentiles
#
# Percentiles for the last-update time. 90th percentile being within 1000ms or so indicates that the topology is keeping up with the throughput.

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0')
plt.show()

print("Percentiles: ", p)
f.savefig("Storm_220_LWU.pdf", bbox_inches='tight')
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %% [markdown]
# ### *Late* Publishes
# Here are the percentiles for the windows that were published *after* the expected 1000ms cutoff:

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0')
plt.show()

# %% [markdown]
# # Flink Benchmarks - 1.11.0 with enableObjectReuse

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_reuse/FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results_flink_reuse/FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results_flink_reuse/FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results_flink_reuse/FLINK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results_flink_reuse/FLINK/130000/updated.txt", "purple", "130000"),
         ("../runs/results_flink_reuse/FLINK/130000/updated.txt", "purple", "135000"),
         ("../runs/results_flink_reuse/FLINK/150000/updated.txt", "orange", "150000"),
         ("../runs/results_flink_reuse/FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink 1.11.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_110_reuse_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0')
plt.grid(True)
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_110_LWU_reuse.pdf", bbox_inches='tight')
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %% [markdown]
# # Flink Benchmarks - 1.11.0

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink-1.11.0/FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results_flink-1.11.0/FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results_flink-1.11.0/FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results_flink-1.11.0/FLINK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results_flink-1.11.0/FLINK/130000/updated.txt", "purple", "130000"),
         ("../runs/results_flink-1.11.0/FLINK/130000/updated.txt", "purple", "135000"),
         ("../runs/results_flink-1.11.0/FLINK/150000/updated.txt", "orange", "150000"),
         ("../runs/results_flink-1.11.0/FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink 1.11.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_110_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0')
plt.grid(True)
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_110_LWU.pdf", bbox_inches='tight')
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0')
plt.show()

# %% [markdown]
# # DStream Spark Benchmarks - 3.0 - Micro batch interval 3 secs

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/SPARK/50000/updated.txt", "green", "50000"),
         ("../runs/results/SPARK/70000/updated.txt", "red", "70000"),
         ("../runs/results/SPARK/90000/updated.txt", "blue", "90000"),
         ("../runs/results/SPARK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results/SPARK/130000/updated.txt", "purple", "130000"),
         ("../runs/results/SPARK/135000/updated.txt", "purple", "135000"),
         ("../runs/results/SPARK/150000/updated.txt", "orange", "150000"),
         ("../runs/results/SPARK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Spark DStream - 3.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Spark_DStream_30_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark DStream - 3.0')
plt.show()
f.savefig("Spark_DStream_30_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark DStream 3.0')
plt.show()

# %% [markdown]
# # Spark Structured Streaming Benchmarks 3.0 - Continuous Mode - Trigger 1s

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/SS_SPARK/50000/updated.txt", "green", "50000"),
         ("../runs/results/SS_SPARK/70000/updated.txt", "red", "70000"),
         ("../runs/results/SS_SPARK/90000/updated.txt", "blue", "90000"),
         ("../runs/results/SS_SPARK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results/SS_SPARK/130000/updated.txt", "purple", "130000"),
         ("../runs/results/SS_SPARK/130000/updated.txt", "purple", "135000"),
         ("../runs/results/SS_SPARK/150000/updated.txt", "orange", "150000"),
         ("../runs/results/SS_SPARK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Spark SS 3.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Spark_SS_30_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.yticks(np.arange(0,12000,1000))
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark SS  3.0')
plt.show()
f.savefig("Spark_SS_30_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [
         #("../runs/results_ss_spark_2/SS_SPARK/50000/updated.txt", "green", "50000"),
         ("../runs/results_ss_spark_2/SS_SPARK/70000/worker1/updated.txt", "red", "70000"),
         ("../runs/results_ss_spark_2/SS_SPARK/90000/updated.txt", "blue", "90000"),
         #("../runs/results_ss_spark_2/SS_SPARK/110000/worker1/updated.txt", "yellow", "110000"),
         #("../runs/results_ss_spark_2/SS_SPARK/130000/worker1/updated.txt", "purple", "130000"),
         #("../runs/results_ss_spark_2/SS_SPARK/135000/updated.txt", "purple", "135000"),
         #("../runs/results_ss_spark_2/SS_SPARK/150000/updated.txt", "orange", "150000"),
         #("../runs/results_ss_spark_2/SS_SPARK/170000/updated.txt", "black", "170000")
         ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Spark SS 3.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Spark_SS_30_hist_1.pdf", bbox_inches='tight')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.yticks(np.arange(0,12000,1000))
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark SS  3.0')
plt.show()
f.savefig("Spark_SS_30_LWU_1.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.yticks(np.arange(0,12000,1000))
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark SS - 3.0')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-2751d8eec297> in <module>
#      11
#      12 for (sorted_each, _, label) in sorted:
# ---> 13     filtered_sorted.append(filter_and_sort(sorted_each, _, label))
#      14
#      15 # Do the actual drawing
#
# <ipython-input-52-2751d8eec297> in filter_and_sort(sorted_each, _, label)
#       4 def filter_and_sort(sorted_each, _, label):
#       5     filtered_sorted = [x for x in sorted_each if x > 1000]
# ----> 6     perc = np.percentile(filtered_sorted, p)
#       7     return (filtered_sorted, perc, label)
#       8
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3704         raise ValueError("Percentiles must be in the range [0, 100]")
#    3705     return _quantile_unchecked(
# -> 3706         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3707
#    3708
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3824     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3825                     overwrite_input=overwrite_input,
# -> 3826                     interpolation=interpolation)
#    3827     if keepdims:
#    3828         return r.reshape(q.shape + k)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3401         keepdim = (1,) * a.ndim
#    3402
# -> 3403     r = func(a, **kwargs)
#    3404     return r, keepdim
#    3405
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3939             n = np.isnan(ap[-1:, ...])
#    3940
# -> 3941         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3942         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3943
#
# <__array_function__ internals> in take(*args, **kwargs)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in take(a, indices, axis, out, mode)
#     192            [5, 7]])
#     193     """
# --> 194     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     195
#     196
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# IndexError: cannot do a non-empty take from an empty axes.

# %% [markdown]
# # Beam Flink Runner Benchmarks - 1.9.0 (beam-flink-runner-1.9 Beam 2.22.0)

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/BEAM_FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results/BEAM_FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results/BEAM_FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results/BEAM_FLINK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results/BEAM_FLINK/130000/updated.txt", "purple", "130000"),
         ("../runs/results/BEAM_FLINK/135000/updated.txt", "purple", "135000"),
         # Beam cannot keep up at 150000 events
         ("../runs/results/BEAM_FLINK/150000/updated.txt", "orange", "150000")]
         #("../runs/results/BEAM_FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Beam Flink Runner 1.9/2.22.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Beam_Flink_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Flink Runner 1.9/2.22.0')
plt.show()
f.savefig("Beam_Flink_LWU_150k.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/BEAM_FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results/BEAM_FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results/BEAM_FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results/BEAM_FLINK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results/BEAM_FLINK/130000/updated.txt", "purple", "130000"),
         ("../runs/results/BEAM_FLINK/135000/updated.txt", "purple", "135000"),
         # Beam cannot keep up at 150000 events
         ("../runs/results/BEAM_FLINK/150000/updated.txt", "orange", "150000"),
         ("../runs/results/BEAM_FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Flink Runner 1.9/2.22.0')
plt.show()
f.savefig("Beam_Flink_LWU_170k.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Flink Runner 1.9/2.22.0')
plt.show()

# %% [markdown]
# # Beam Spark Runner Benchmarks - (beam-spark-runner Beam 2.22.0 on Spark 2.4.6) Micro batch interval 3 secs
# Note: Spark Structured Streaming for Beam only supports Bounded batch processing hence not useful to perform benchmarks for streaming frameworks

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/BEAM_SPARK/50000/updated.txt", "green", "50000"),
         ("../runs/results/BEAM_SPARK/70000/updated.txt", "red", "70000"),
         ("../runs/results/BEAM_SPARK/90000/updated.txt", "blue", "90000")]
         #("./results/BEAM_SPARK/110000/updated.txt", "yellow", "110000"),
         #("./results/BEAM_SPARK/130000/updated.txt", "purple", "130000"),
         #("./results/BEAM_SPARK/135000/updated.txt", "purple", "135000"),
         #("./results/BEAM_SPARK/150000/updated.txt", "orange", "150000"),
         #("./results/BEAM_SPARK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Beam Spark Runner 2.4.6/2.22.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Beam_Spark_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Spark Runner 2.4.6/2.22.0')
plt.show()
f.savefig("Beam_Spark_LWU_90k.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %%
# Percentile values
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/BEAM_SPARK/50000/updated.txt", "green", "50000"),
         ("../runs/results/BEAM_SPARK/70000/updated.txt", "red", "70000")]
         #("../runs/results/BEAM_SPARK/90000/updated.txt", "blue", "90000")]
         #("./results/BEAM_SPARK/110000/updated.txt", "yellow", "110000"),
         #("./results/BEAM_SPARK/130000/updated.txt", "purple", "130000"),
         #("./results/BEAM_SPARK/135000/updated.txt", "purple", "135000"),
         #("./results/BEAM_SPARK/150000/updated.txt", "orange", "150000"),
         #("./results/BEAM_SPARK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]

p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Spark Runner 2.4.6/2.22.0')
plt.show()

# %% [markdown]
# # Benchmarks with acking/checkpoints enabled

# %% [markdown]
# # Storm 10 Ackers

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_chkpt/STORM/50000/updated.txt", "green", "50000"),
         ("../runs/results_chkpt/STORM/70000/updated.txt", "red", "70000"),
         ("../runs/results_chkpt/STORM/90000/updated.txt", "blue", "90000"),
         ("../runs/results_chkpt/STORM/110000/updated.txt", "yellow", "110000"),
         ("../runs/results_chkpt/STORM/130000/updated.txt", "purple", "130000"),
         ("../runs/results_chkpt/STORM/135000/updated.txt", "purple", "135000"),
         ("../runs/results_chkpt/STORM/150000/updated.txt", "orange", "150000"),
         ("../runs/results_chkpt/STORM/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (10 Ackers)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0/10 Ackers')
plt.legend(loc="upper right")
plt.show()
f.savefig("Storm_220_hist_Acking.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0/10 Ackers')
plt.show()

print("Percentiles: ", p)
f.savefig("Storm_220_LWU_Acking.pdf", bbox_inches='tight')

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0/10 Ackers')
plt.show()

# %% [markdown]
# # Flink with checkpointing enabled - checkpointing interval 1s

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_chkpt/FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results_chkpt/FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results_chkpt/FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results_chkpt/FLINK/110000/updated.txt", "yellow", "110000"),
         ("../runs/results_chkpt/FLINK/130000/updated.txt", "purple", "130000"),
         ("../runs/results_chkpt/FLINK/135000/updated.txt", "purple", "135000"),
         ("../runs/results_chkpt/FLINK/150000/updated.txt", "orange", "150000"),
         ("../runs/results_chkpt/FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpoint Interval - 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink 1.11.0 Checkpoint Interval(1s)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_110_hist_checkpoint.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpoint Interval - 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0 Checkpoint Interval(1s)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_110_LWU_checkpoint.pdf", bbox_inches='tight')

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0 Checkpoint Interval(1s)')
plt.show()

# %% [markdown]
# # Beam Flink with checkpointing interval - 1s

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_chkpt/BEAM_FLINK/50000/updated.txt", "green", "50000"),
         ("../runs/results_chkpt/BEAM_FLINK/70000/updated.txt", "red", "70000"),
         ("../runs/results_chkpt/BEAM_FLINK/90000/updated.txt", "blue", "90000"),
         ("../runs/results_chkpt/BEAM_FLINK/110000/updated.txt", "yellow", "110000")]
         #("../runs/results_chkpt/BEAM_FLINK/130000/updated.txt", "purple", "130000")]
         #("../runs/results_chkpt/BEAM_FLINK/135000/updated.txt", "purple", "135000")]
         #("../runs/results_chkpt/BEAM_FLINK/150000/updated.txt", "orange", "150000"),
         #("../runs/results_chkpt/BEAM_FLINK/170000/updated.txt", "black", "170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Beam Flink 1.9.0/2.22.0 Checkpoint Interval(1s)')
plt.legend(loc="upper right")
plt.show()

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpoint Interval - 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Flink 1.9.0/2.22.0 Checkpoint Interval(1s)')
plt.show()
f.savefig("Beam_Flink_LWU_checkpoint.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Beam Flink 1.9.0/2.22.0 Checkpoint Interval(1s)')
plt.show()

# %% [markdown]
# # Storm latency/throughput for higher rate of events 200K/s to 400K/s Parallelism with 8x parallelism for bolts

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_4k/STORM/200000/updated.txt", "green", "200000"),
         ("../runs/results_4k/STORM/250000/updated.txt", "red", "250000"),
         ("../runs/results_4k/STORM/300000/updated.txt", "blue", "300000"),
         ("../runs/results_4k/STORM/350000/updated.txt", "yellow", "350000"),
         ("../runs/results_4k/STORM/400000/updated.txt", "violet", "400000")]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0 (No acking)')
plt.legend(loc="upper right")
plt.show()

# %%
# Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0 (No acking)')
plt.show()

f.savefig("Storm_220_200k-400k_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0 (No acking)')
plt.show()

# %% [markdown]
# # Flink latency/throughput for higher rate of events 200K/s to 400K/s Parallelism with 8x parallelism for bolts

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_4k/FLINK/200000/updated.txt", "green", "200000"),
         ("../runs/results_4k/FLINK/250000/updated.txt", "red", "250000"),
         ("../runs/results_4k/FLINK/300000/updated.txt", "blue", "300000"),
         ("../runs/results_4k/FLINK/350000/updated.txt", "pink", "350000"),
         ("../runs/results_4k/FLINK/400000/updated.txt", "yellow", "400000")]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink 1.11.0')
plt.legend(loc="upper right")
plt.show()

# %%
# Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0')
plt.show()
f.savefig("Flink_110_200k-400k_LWU.pdf", bbox_inches='tight')

print("Percentiles: ", p)

# %%
# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

def filter_and_sort(sorted_each, _, label):
    filtered_sorted = [x for x in sorted_each if x > 1000]
    perc = np.percentile(filtered_sorted, p)
    return (filtered_sorted, perc, label)

# Filter all data points <= 1000 ms
filtered_sorted = list()

for (sorted_each, _, label) in sorted:
    filtered_sorted.append(filter_and_sort(sorted_each, _, label))

# Do the actual drawing
plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in filtered_sorted:
    draw_line(points, percentiles, label)
    
plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After 1000ms Expected Cutoff')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink 1.11.0')
plt.show

# %% [markdown]
# # Storm/Flink Worker node Utilization with higher parallelism and higher rate of events

# %%
def get_utilization_stats(filename):
    utilization = np.loadtxt(filename, dtype=float)
    return utilization

def draw_line(points, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label))

# %%
files = [("../runs/cpu/storm_ysar_200_400_cpu_final.txt", "Storm CPU 200K/s-400K/s (Parallelism:432)"),
         ("../runs/cpu/storm_ysar_200_400_cpu_half_parallelism.txt", "Storm CPU 200K/s-400K/s(Parallelism:216)"),
         ("../runs/cpu/flink_ysar_200_400_cpu_final.txt", "Flink CPU 200K/s-400K/s")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('CPU Utilization %')
plt.grid(True)
plt.title('Storm/Flink Memory Utilization for 200K, 250K, 300K, 350K, 400K events/sec over a period of time (Parallelism 432)')
plt.show()
f.savefig("Storm_Flink_CPU_200k-400k.pdf", bbox_inches='tight')

# %%
files = [("../runs/mem/storm_ysar_200_400_mem_final.txt", "Storm MEM 200K/s-400K/s"),
         ("../runs/mem/flink_ysar_200_400_mem_final.txt", "FLink MEM 200K/s-400K/s (taskmanager.memory.managed.fraction: 0.1)"),
         ("../runs/flink_ysar_200_400_mem.txt", "FLink MEM 200K/s-400K/s (taskmanager.memory.managed.fraction: 0.4)")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.yticks(np.arange(0,100,10))
plt.ylabel('Memory Utilization %')
plt.grid(True)
plt.title('Storm/Flink Memory Utilization for 200K, 250K, 300K, 350K, 400K events/sec over a period of time (Parallelism 432)')
plt.show()
f.savefig("Storm_Flink_MEM_200k-400k.pdf", bbox_inches='tight')

# %%
files = [("../runs/network/storm_ysar_200_400_inkbps_final.txt", "Storm inkbps"),
         ("../runs/network/storm_ysar_200_400_outkbps_final.txt", "Storm outkbps"),
         ("../runs/network/flink_ysar_200_400_inkbps_final.txt", "Flink inkbps"),
         ("../runs/network/flink_ysar_200_400_outkbps_final.txt", "Flink outkbps")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('Network Utilization(kbps)')
plt.grid(True)
plt.title('Storm/Flink Network Utilization for 200K, 250K, 300K, 350K, 400K events/sec over a period of time (Parallelism 432)')
plt.show()
f.savefig("Storm_Flink_Network_200k-400k.pdf", bbox_inches='tight')

# %%
files = [("../runs/cpu/storm_ysar_50_170_cpu_final.txt", "Storm CPU 50k/s-170k/s"),
         ("../runs/cpu/spark_dstream_ysar_50_170_cpu_final.txt", "Spark DStream CPU 50k/s-170k/s"),
         ("../runs/cpu/flink_ysar_50_170_cpu_final.txt", "Flink CPU 200K/s-400K/s")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('CPU Utilization %')
plt.grid(True)
plt.title('Storm/Spark/Flink CPU Utilization for 50K, 70K, 90K, 110K, 130K, 135K, 150K, 170K events/sec over a period of time (Parallelism 72)')
plt.show()
f.savefig("Storm_Flink_Spark_CPU_50k-170k.pdf", bbox_inches='tight')

# %%
files = [("../runs/mem/storm_ysar_50_170_mem_final.txt", "Storm MEM 50k/s-170k/s"),
         ("../runs/mem/spark_dstream_ysar_50_170_mem_final.txt", "Spark DStream MEM 50k/s-170k/s"),
         ("../runs/mem/flink_ysar_50_170_mem_final.txt", "Flink MEM 200K/s-400K/s (taskmanager.memory.managed.fraction: 0.1)"),
         ("../runs/flink_50_170_tm_06.txt", "Flink MEM 200K/s-400K/s (taskmanager.memory.managed.fraction: 0.6)")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('Memory Utilization %')
plt.yticks(np.arange(0,100,10))
plt.grid(True)
plt.title('Storm/Spark/Flink Memory Utilization for 50K, 70K, 90K, 110K, 130K, 135K, 150K, 170K events/sec over a period of time (Parallelism 72)')
plt.show()
f.savefig("Storm_Flink_Spark_MEM_50k-170k.pdf", bbox_inches='tight')

# %%
files = [("../runs/network/storm_ysar_50_170_inkbps_final.txt", "Storm inkbps"),
         ("../runs/network/spark_dstream_ysar_50_170_inkbps_final.txt", "Spark inkbps"),
         ("../runs/network/flink_ysar_50_170_inkbps_final.txt", "Flink inkbps"),
         ("../runs/network/storm_ysar_50_170_outkbps_final.txt", "Storm outkbps"),
         ("../runs/network/spark_dstream_ysar_50_170_outkbps_final.txt", "Spark outkbps"),
         ("../runs/network/flink_ysar_50_170_outkbps_final.txt", "Flink outkbps")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('Network Utilization(kbps)')
plt.grid(True)
plt.title('Storm/Spark/Flink Network Utilization for 50K, 70K, 90K, 110K, 130K, 135K, 150K, 170K events/sec over a period of time (Parallelism 72)')
plt.show()
f.savefig("Storm_Flink_Spark_Network_50k-170k.pdf", bbox_inches='tight')

# %%
files = [("../runs/mem/storm_ysar_200_400_mem_final.txt", "Storm MEM (G1GC) 200K/s-400K/s"),
         ("../runs/storm_ysar_200_400_mem.txt", "Storm MEM (CMS) 200K/s-400K/s")]

utilization_stats = [(get_utilization_stats(filename), label) for (filename, label) in files]

f = plt.figure(num=None, figsize=(15, 10))
for (points,label) in utilization_stats:
    draw_line(points,label)

plt.legend(loc="upper left")
plt.xlabel('Time Minutes')
plt.ylabel('Mem Utilization %')
plt.grid(True)
plt.title('Storm/Flink Memory Utilization for 200K, 250K, 300K, 350K, 400K events/sec over a period of time (Parallelism 432)')
plt.show()
f.savefig("Storm_Flink_MEM_CMS_G1GC_200k-400k.pdf", bbox_inches='tight')

# %% [markdown]
# # Latest numbers for Storm/Spark/Flink

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [#("../runs/results_4k/STORM/200000/updated.txt", "green", "200000"),
         #("../runs/results_4k/STORM/250000/updated.txt", "red", "250000"),
         #("../runs/results_4k/STORM/300000/updated.txt", "blue", "300000"),
         #("../runs/results_4k/STORM/350000/updated.txt", "yellow", "350000"),
         #("../runs/results_4k/STORM/400000/updated.txt", "violet", "400000"),
         #("../runs/results_600k_1m/600000/updated.txt", "magenta", "600000"),
          ("../runs/results_600k_1m/600000_1/updated.txt", "black", "600000_1"),
          ("../runs/results_600k_1m/600000_2/updated.txt", "red", "600000_2"),
          ("../runs/results_600k_1m/800000_4/updated.txt", "blue", "800000_4"),
          ("../runs/results_600k_1m/800000_5/updated.txt", "violet", "800000_5")]
         #("../runs/results_600k_1m/800000/updated.txt", "black", "800000"),
         #("../runs/results_600k_1m/800000_1/updated.txt", "black", "800000")]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0 (No acking)')
plt.legend(loc="upper right")
plt.show()

# %%
# Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm 2.2.0 (No acking)')
plt.show()

f.savefig("Storm_220_200k-400k_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)

# %% [markdown]
# # Storm Trident Micro Batch (Batch Interval - 20ms) Parallelism=72

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/TRIDENT_STORM/50000/updated.txt", "blue", "50000"),
         ("../runs/results/TRIDENT_STORM/70000/updated.txt", "red", "70000"),
         ("../runs/results/TRIDENT_STORM/90000/updated.txt", "green", "90000"),
         ("../runs/results/TRIDENT_STORM/110000/updated.txt", "orange", "110000"),
         ("../runs/results/TRIDENT_STORM/130000/updated.txt", "cyan", "130000")
         #("../runs/results/TRIDENT_STORM/150000/updated.txt", "black", "150000")
        ]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
#print(filtered)
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm Trident 2.2.0')
plt.legend(loc="upper right")
plt.show()

# %%
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

#print(filtered)
sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]
#print(sorted)
# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm Trident - 2.2.0')
plt.show()
f.savefig("Storm_Trident_20ms.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %% [markdown]
# # Storm Trident Batch (Batch Interval - 20ms) Parallelism=216

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [#("../runs/results_trident/TRIDENT_STORM/50000/updated.txt", "blue", "50000"),
         ("../runs/results_trident/TRIDENT_STORM/70000/updated.txt", "red", "70000"),
         ("../runs/results_trident/TRIDENT_STORM/90000/updated.txt", "green", "90000"),
         ("../runs/results_trident/TRIDENT_STORM/110000/updated.txt", "orange", "110000"),
         ("../runs/results_trident/TRIDENT_STORM/130000/updated.txt", "cyan", "130000"),
         ("../runs/results_trident/TRIDENT_STORM/150000/updated.txt", "black", "150000"),
         ("../runs/results_trident/TRIDENT_STORM/170000/updated.txt", "magenta", "170000")
        ]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

plt.figure(num=None, figsize=(15, 10))
#print(filtered)
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm Trident 2.2.0 (Parallelism=216)')
plt.legend(loc="upper right")
plt.show()

# %%
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

#print(filtered)
sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]
#print(sorted)
# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm Trident - 2.2.0(Parallelism=216)')
plt.show()
f.savefig("Spark_DStream_30_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %% [markdown]
# # Spark Structured Streaming Micro Batch Trigger 3s

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_ss_spark/SS_SPARK/50000/updated.txt", "blue", "50000"),
         ("../runs/results_ss_spark/SS_SPARK/70000/updated.txt", "red", "70000"),
         ("../runs/results_ss_spark/SS_SPARK/90000/updated.txt", "green", "90000")
         #("../runs/results_ss_spark/SS_SPARK/110000/updated.txt", "orange", "110000"),
         #("../runs/results_ss_spark/SS_SPARK/130000/updated.txt", "cyan", "130000"),
         #("../runs/results_ss_spark/SS_SPARK/150000/updated.txt", "black", "150000"),
        ]
         
filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 100000, 100)

plt.figure(num=None, figsize=(15, 10))
#print(filtered)
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Spark Structured Streaming Micro Batch (3 seconds)')
plt.legend(loc="upper right")
plt.show()

# %%
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

#print(filtered)
sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]
#print(sorted)
# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark Structured Streaming Micro Batch (3 seconds)')
plt.show()
f.savefig("Spark_SS_3s_MicroBatch_LWU.pdf", bbox_inches='tight')
print("Percentiles: ", p)
# Out:
# Percentiles:  [ 1. 10. 25. 50. 75. 90. 99.]

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def get_filtered_updated(filename, window_size_ms):
    update_times = np.loadtxt(filename, dtype=int)
    filtered_times = [x - window_size_ms for x in update_times if x >= window_size_ms]
    return filtered_times

# %% [markdown]
# # Storm Flink 170k Combined Graph (Without Checkpointing)

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results/FLINK/170000/updated.txt", "orange", "Flink-1.11.0 170000"),
         ("../runs/results/STORM/170000/updated.txt", "black", "Storm-2.2.0 170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (No Checkpointing)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Storm_Flink_170k_no_chkpt_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (No Checkpointing)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm-2.2.0 Flink-1.11.0 170k/s')
plt.show()

print("Percentiles: ", p)
f.savefig("Storm_Flink_170k_no_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # Storm Flink 170k Combined Graph (With Checkpointing)

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_chkpt/FLINK/170000/updated.txt", "orange", "Flink-1.11.0 170000"),
         ("../runs/results_chkpt/STORM/170000/updated.txt", "black", "Storm-2.2.0 170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Storm_Flink_170k_with_chkpt_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm-2.2.0 Flink-1.11.0 170k/s')
plt.show()

print("Percentiles: ", p)
f.savefig("Storm_Flink_170k_with_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # Storm Flink Structured Streaming Combined (With Checkpointing)

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_chkpt/FLINK/170000/updated.txt", "orange", "Flink-1.11.0 170000"),
         ("../runs/results_chkpt/STORM/170000/updated.txt", "black", "Storm-2.2.0 170000"),
         ("../runs/results/SS_SPARK/170000/updated.txt", "blue", "Spark Structured Streaming-3.0 170000")]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Storm 2.2.0')
plt.legend(loc="upper right")
plt.show()
f.savefig("Storm_Flink_SS_170k_with_chkpt_hist.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Storm-2.2.0 Flink-1.11.0 170k/s')
plt.show()

print("Percentiles: ", p)
f.savefig("Storm_Flink_SS_170k_with_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # Flink on Yarn with Checkpointing interval of 1s

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def get_filtered_updated(filename, window_size_ms):
    update_times = np.loadtxt(filename, dtype=int)
    filtered_times = [x - window_size_ms for x in update_times if x >= window_size_ms]
    return filtered_times

# %% [markdown]
# # 1 worker checkpointing enabled

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/FLINK_YARN_CHKPT/50000/worker1/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/70000/worker1/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/90000/worker1/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/110000/worker1/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/130000/worker1/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/135000/worker1/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/150000/worker1/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (1 worker)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_1_workers_chkpt.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (1 worker)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_1_workers_chkpt.pdf", bbox_inches='tight')

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/FLINK_YARN_CHKPT/50000/worker1run2/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/70000/worker1run2/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/90000/worker1run2/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/110000/worker1run2/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/130000/worker1run2/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/135000/worker1run2/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         #("../runs/results_flink_yarn/FLINK_YARN_CHKPT/150000/worker1/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         #("../runs/results_flink_yarn/FLINK_YARN_CHKPT/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (1 worker)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_1_workers_chkpt.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (1 worker)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_1_workers_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # 2 workers checkpointing enabled

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/FLINK_YARN_CHKPT/50000/worker2/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/70000/worker2/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/90000/worker2/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/110000/worker2/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/130000/worker2/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/135000/worker2/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/150000/worker2/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/170000/worker2/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (2 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_2_workers_chkpt.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (2 workers)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_2_workers_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # 4 workers checkpointing enabled

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/FLINK_YARN_CHKPT/50000/worker4/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/70000/worker4/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/90000/worker4/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/110000/worker4/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/130000/worker4/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/135000/worker4/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/150000/worker4/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/170000/worker4/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (4 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_4_workers_chkpt.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (4 workers)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_4_workers_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # 8 workers checkpointing enabled

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/FLINK_YARN_CHKPT/50000/worker4/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/70000/worker4/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/90000/worker4/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/110000/worker4/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/130000/worker4/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/135000/worker4/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/150000/worker4/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/FLINK_YARN_CHKPT/170000/worker4/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (Checkpointing Interval 1s)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (8 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_8_workers_chkpt.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (Checkpointing Interval 1s)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (8 workers)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_8_workers_chkpt.pdf", bbox_inches='tight')

# %% [markdown]
# # Flink on Yarn without Checkpointing

# %% [markdown]
# # 1 workers no checkpointing

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/50000/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/70000/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/90000/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/110000/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/130000/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/135000/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/150000/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/flink_yarn_worker1/FLINK_YARN/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (No Checkpointing)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (1 worker)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_1_workers.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (No Checkpointing)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (1 worker, no checkpointing)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_1_workers.pdf", bbox_inches='tight')

# %% [markdown]
# # 2 workers no checkpointing

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/50000/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/70000/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/90000/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/110000/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/130000/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/135000/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/150000/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/flink_yarn_worker2/FLINK_YARN/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (No Checkpointing)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (2 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_2_workers.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (No Checkpointing)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (2 workers, no checkpointing)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_2_workers.pdf", bbox_inches='tight')

# %% [markdown]
# # 4 workers no checkpointing

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/50000/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/70000/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/90000/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/110000/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/130000/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/135000/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/150000/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/flink_yarn_worker4/FLINK_YARN/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (No Checkpointing)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (4 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_4_workers.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (No Checkpointing)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (4 workers, no checkpointing)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_4_workers.pdf", bbox_inches='tight')

# %% [markdown]
# # 8 workers no checkpointing

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/50000/updated.txt", "orange", "Flink on Yarn (1.11.0) 50000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/70000/updated.txt", "black", "Flink on Yarn (1.11.0) 70000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/90000/updated.txt", "blue", "Flink on Yarn (1.11.0) 90000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/110000/updated.txt", "grey", "Flink on Yarn (1.11.0) 110000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/130000/updated.txt", "green", "Flink on Yarn (1.11.0) 130000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/135000/updated.txt", "red", "Flink on Yarn (1.11.0) 135000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/150000/updated.txt", "magenta", "Flink on Yarn (1.11.0) 150000"),
         ("../runs/results_flink_yarn/flink_yarn_worker8/FLINK_YARN/170000/updated.txt", "yellow", "Flink on Yarn (1.11.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s (No Checkpointing)") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Flink on Yarn 2.2.0 (8 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Flink_on_yarn_50k_170_8_workers.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s (No Checkpointing)"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Flink on Yarn 1.11.0 170k/s (8 workers, no checkpointing)')
plt.show()

print("Percentiles: ", p)
f.savefig("Flink_on_yarn_LWU_50k_170_8_workers.pdf", bbox_inches='tight')

# %% [markdown]
# # Spark on Yarn

# %%
window_size_ms = 10000   #10 seconds (for me). Adjust to match your benchmark and common component.

files = [("../runs/results_spark_yarn/SPARK_YARN/50000/worker1/updated.txt", "orange", "Spark on Yarn (3.0.0) 50000"),
         ("../runs/results_spark_yarn/SPARK_YARN/70000/worker1/updated.txt", "black", "Spark on Yarn (3.0.0) 70000"),
         ("../runs/results_spark_yarn/SPARK_YARN/90000/worker1/updated.txt", "blue", "Spark on Yarn (3.0.0) 90000"),
         ("../runs/results_spark_yarn/SPARK_YARN/110000/worker1/updated.txt", "grey", "Spark on Yarn (3.0.0) 110000"),
         ("../runs/results_spark_yarn/SPARK_YARN/130000/worker1/updated.txt", "green", "Spark on Yarn (3.0.0) 130000"),
         ("../runs/results_spark_yarn/SPARK_YARN/135000/worker1/updated.txt", "red", "Spark on Yarn (3.0.0) 135000"),
         ("../runs/results_spark_yarn/SPARK_YARN/150000/worker1/updated.txt", "magenta", "Spark on Yarn (3.0.0) 150000"),
         ("../runs/results_spark_yarn/SPARK_YARN/170000/worker1/updated.txt", "yellow", "Spark on Yarn (3.0.0) 170000")
        ]

filtered = [(get_filtered_updated(filename, window_size_ms), color, label) for (filename, color, label) in files]
bins = np.linspace(0, 10000, 100)

f = plt.figure(num=None, figsize=(15, 10))
for (filter_each, color, label) in filtered:
    plt.hist(filter_each, bins, density=1, facecolor=color, alpha=0.5, label=label+"/s") 
plt.xlabel('Last update time (in ms after window ended)')
plt.ylabel('Window Count')
plt.title('Histogram of Last Window Update Times (Estimated end-to-end latency) - Spark on Yarn 3.0.0 (1 workers)')
plt.legend(loc="upper right")
plt.show()
f.savefig("Spark_on_yarn_50k_170_1_workers.pdf", bbox_inches='tight')

# %%
#Draws percentile charts from tuples of ([points], [percentiles], label)
def draw_line(points, percentiles, label):    
    plt.plot(np.linspace(0,100, len(points)), points, label=(label + "/s"))
    plt.plot(p, percentiles, 'ro')

# Percentile values
p = np.array([1.0, 10.0, 25.0, 50.0, 75.0, 90.0, 99.0])

sorted = [(np.sort(filter), np.percentile(np.sort(filter), p), label) for (filter, _, label) in filtered]

# Do the drawing
f = plt.figure(num=None, figsize=(15, 10))

for (points, percentiles, label) in sorted:
    draw_line(points, percentiles,label)

plt.legend(loc="upper left")
plt.xlabel('Percent of Tuples Complete [ 1. 10. 25. 50. 75. 90. 99.]')
plt.ylabel('Time (ms) After Window Closed')
plt.grid(True)
plt.title('Percentile Comparison of Last Window Update Times - Spark on Yarn 3.0.0 170k/s (1 workers)')
plt.show()

print("Percentiles: ", p)
f.savefig("Spark_on_yarn_LWU_50k_170_1_workers_chkpt.pdf", bbox_inches='tight')
